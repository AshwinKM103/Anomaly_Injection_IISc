# %%
import numpy as np
import pandas as pd
import time
import os
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import f1_score,precision_score,recall_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical
from typing import List, Dict
from sklearn.metrics import make_scorer
from tqdm import tqdm
from sklearn.base import BaseEstimator, ClassifierMixin


seed = 42

# %%
class LOFWrapper(BaseEstimator, ClassifierMixin):
    """
    A scikit-learn-compatible wrapper for LocalOutlierFactor to work with BayesSearchCV.
    Enables supervised scoring and sets required attributes.
    """

    def __init__(self, **params):
        self.params = params
        self.model = None

    def fit(self, X, y=None):
        # novelty=True allows for a separate .predict() after fit
        self.model = LocalOutlierFactor(novelty=True, **self.params)
        self.model.fit(X)
        self.classes_ = np.array([0, 1])  # Required for scoring API compatibility
        return self

    def predict(self, X):
        return np.where(self.model.predict(X) == -1, 1, 0)

    def get_params(self, deep=True):
        return self.params

    def set_params(self, **params):
        self.params.update(params)
        return self

# %%
def tune_lof_bayesian_search(X_train, y_train, search_iter=30):
    """
    Use Bayesian optimization to tune LOF hyperparameters.

    Parameters
    ----------
    X_train : np.ndarray
        Scaled input features.
    y_train : np.ndarray
        Ground truth binary labels (1 = anomaly, 0 = normal).
    search_iter : int
        Number of search iterations.

    Returns
    -------
    dict
        Best hyperparameters found via optimization.
    """
    search_space = {
        "n_neighbors": Integer(5, 100),
        "leaf_size": Integer(10, 100),
        "p": Integer(1, 3),
        "metric": Categorical(["minkowski", "manhattan", "euclidean"]),
        "contamination": Real(0.01, 0.1, prior='log-uniform')
    }

    optimizer = BayesSearchCV(
        estimator=LOFWrapper(),
        search_spaces=search_space,
        scoring=make_scorer(f1_score),
        n_iter=search_iter,
        cv=3,
        verbose=0,
        n_jobs=-1
    )
    optimizer.fit(X_train, y_train)
    return optimizer.best_params_

# %%
def evaluate_all_buildings_lof(
    all_files,
    path,
    anomaly_type,
    search_iter=30
):
    """
    Evaluate LOF across buildings using tuned hyperparameters.

    Parameters
    ----------
    all_files : list of str
        List of .csv files per building.
    path : str
        Folder where the building files are stored.
    anomaly_type : int
        Label to match for anomalies (e.g. 2, 3, 4).
    search_iter : int
        Number of BayesSearchCV iterations.

    Returns
    -------
    pd.DataFrame
        Summary of evaluation results per building.
    """
    records = []

    for file in tqdm(all_files, desc=f"LOF Tuning for Type {anomaly_type}"):
        try:
            df = pd.read_csv(os.path.join(path, file))
            X = df['modified'].values.reshape(-1, 1)
            y = np.where(df['labels'] == anomaly_type, 1, 0)
            X_scaled = StandardScaler().fit_transform(X)

            best_params = tune_lof_bayesian_search(X_scaled, y, search_iter)
            model = LocalOutlierFactor(novelty=True, **best_params)
            model.fit(X_scaled)
            y_pred = np.where(model.predict(X_scaled) == -1, 1, 0)

            record = {
                "building_file": file,
                "f1_score": f1_score(y, y_pred, zero_division=0),
                "precision": precision_score(y, y_pred, zero_division=0),
                "recall": recall_score(y, y_pred, zero_division=0),
                **best_params
            }

        except Exception as e:
            record = {
                "building_file": file,
                "f1_score": np.nan,
                "precision": np.nan,
                "recall": np.nan,
                "error": str(e)
            }

        records.append(record)

    return pd.DataFrame(records)

# %%
def run_lof_evaluation_for_all_anomaly_types(
    base_path,
    anomaly_types=[2, 3, 4],
    output_dir="lof_scores",
    search_iter=30
):
    """
    Run LOF tuning + evaluation for all anomaly types (2,3,4).

    Parameters
    ----------
    base_path : str
        Path to folder containing TYPE2/, TYPE3/, etc.
    anomaly_types : list of int
        Anomaly types to evaluate.
    output_dir : str
        Where to store CSV outputs.
    search_iter : int
        Number of Bayesian search iterations.
    """
    os.makedirs(output_dir, exist_ok=True)

    for anom_type in anomaly_types:
        print(f"\n🚀 Running LOF evaluation for anomaly type {anom_type}")
        folder = os.path.join(base_path, f"TYPE{anom_type}")
        files = [f for f in os.listdir(folder) if f.endswith(".csv")]

        summary_df = evaluate_all_buildings_lof(
            all_files=files,
            path=folder,
            anomaly_type=anom_type,
            search_iter=search_iter
        )

        out_path = os.path.join(output_dir, f"lof_type{anom_type}_scores.csv")
        summary_df.to_csv(out_path, index=False)
        print(f"✅ Saved to {out_path}")

# %%
base_injected_path = "/data1/home/nitinvetcha/Ashwin_KM_Code/tsfm_learning/Anomaly_Injection_IISc/injection_code/src/OUTPUT_BDG2/MODIFIED"

run_lof_evaluation_for_all_anomaly_types(
    base_path=base_injected_path,
    anomaly_types=[2, 3, 4],
    output_dir="bdg2_lof_scores",
    search_iter=30
)
# Out:
# 🚀 Running LOF evaluation for anomaly type 2
# LOF Tuning for Type 2:   2%|▏         | 3/200 [01:03<1:06:27, 20.24s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 5, 3] before, using random point [0.05117003219217553, 19, 'minkowski', 20, 2]
#   warnings.warn(
# LOF Tuning for Type 2:   8%|▊         | 16/200 [05:03<56:39, 18.47s/it]  /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 1] before, using random point [0.024264430049378786, 64, 'euclidean', 48, 2]
#   warnings.warn(
# LOF Tuning for Type 2:  33%|███▎      | 66/200 [21:09<40:48, 18.27s/it]  /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 3] before, using random point [0.026740296617348676, 38, 'manhattan', 15, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 3] before, using random point [0.037089971324397654, 43, 'manhattan', 9, 1]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 3] before, using random point [0.030566496378073304, 95, 'manhattan', 31, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 3] before, using random point [0.06031715734892948, 43, 'manhattan', 17, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 3] before, using random point [0.09109381860739355, 14, 'euclidean', 22, 2]
#   warnings.warn(
# LOF Tuning for Type 2:  36%|███▋      | 73/200 [23:24<39:49, 18.81s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.014414735801025086, 66, 'euclidean', 38, 2]
#   warnings.warn(
# LOF Tuning for Type 2:  39%|███▉      | 78/200 [24:58<37:49, 18.60s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 3] before, using random point [0.012684339502532853, 82, 'minkowski', 28, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 3] before, using random point [0.09637721566920965, 91, 'euclidean', 20, 1]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 3] before, using random point [0.017552211342067303, 51, 'manhattan', 37, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 3] before, using random point [0.049592840822968956, 92, 'euclidean', 25, 1]
#   warnings.warn(
# LOF Tuning for Type 2:  40%|███▉      | 79/200 [25:18<38:33, 19.12s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.01, 10, 'euclidean', 50, 3] before, using random point [0.042564072538276564, 48, 'manhattan', 34, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.01, 10, 'minkowski', 50, 3] before, using random point [0.036093561777045285, 55, 'manhattan', 45, 2]
#   warnings.warn(
# LOF Tuning for Type 2:  54%|█████▍    | 108/200 [34:15<28:48, 18.79s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 50, 3] before, using random point [0.08065593011277426, 27, 'manhattan', 32, 2]
#   warnings.warn(
# LOF Tuning for Type 2: 100%|██████████| 200/200 [1:03:38<00:00, 19.09s/it]
# ✅ Saved to lof_scores/lof_type2_scores.csv
#
# 🚀 Running LOF evaluation for anomaly type 3
# LOF Tuning for Type 3:   2%|▏         | 4/200 [01:13<1:00:44, 18.59s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.040908356723708406, 45, 'minkowski', 16, 1]
#   warnings.warn(
# LOF Tuning for Type 3:   8%|▊         | 16/200 [05:01<57:41, 18.81s/it]  /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 1] before, using random point [0.020040169974758732, 27, 'manhattan', 49, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 1] before, using random point [0.0599692413010113, 59, 'euclidean', 25, 3]
#   warnings.warn(
# LOF Tuning for Type 3:  23%|██▎       | 46/200 [14:37<50:20, 19.61s/it]  /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 5, 1] before, using random point [0.0287106491962561, 14, 'euclidean', 35, 3]
#   warnings.warn(
# LOF Tuning for Type 3:  26%|██▌       | 51/200 [16:14<47:41, 19.21s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 50, 1] before, using random point [0.027907537340630197, 92, 'manhattan', 10, 2]
#   warnings.warn(
# LOF Tuning for Type 3:  41%|████      | 82/200 [26:05<37:34, 19.11s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.04977179873744971, 12, 'minkowski', 47, 1]
#   warnings.warn(
# LOF Tuning for Type 3:  56%|█████▌    | 112/200 [35:32<26:48, 18.27s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 2] before, using random point [0.06883643069951817, 84, 'manhattan', 22, 2]
#   warnings.warn(
# LOF Tuning for Type 3:  60%|█████▉    | 119/200 [37:37<24:28, 18.13s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 3] before, using random point [0.014670233242280924, 21, 'manhattan', 27, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 1] before, using random point [0.01422150981455496, 84, 'euclidean', 40, 1]
#   warnings.warn(
# LOF Tuning for Type 3:  67%|██████▋   | 134/200 [42:05<20:29, 18.63s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 50, 1] before, using random point [0.026102324410083522, 46, 'minkowski', 44, 2]
#   warnings.warn(
# LOF Tuning for Type 3:  69%|██████▉   | 138/200 [43:16<18:18, 17.71s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 1] before, using random point [0.013192367279535102, 72, 'euclidean', 35, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 1] before, using random point [0.01328928448295052, 21, 'euclidean', 35, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 1] before, using random point [0.047934626061677844, 56, 'minkowski', 36, 2]
#   warnings.warn(
# LOF Tuning for Type 3:  70%|██████▉   | 139/200 [43:36<18:38, 18.34s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 1] before, using random point [0.04323449860096044, 70, 'minkowski', 40, 1]
#   warnings.warn(
# LOF Tuning for Type 3:  80%|███████▉  | 159/200 [49:37<12:48, 18.75s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.014910270705116534, 92, 'euclidean', 44, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.03456593641029942, 84, 'manhattan', 11, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 1] before, using random point [0.028020331788805964, 70, 'minkowski', 12, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.061398448429297085, 13, 'minkowski', 7, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.06764511976257859, 35, 'euclidean', 31, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.0690482948269177, 77, 'euclidean', 36, 2]
#   warnings.warn(
# LOF Tuning for Type 3:  86%|████████▋ | 173/200 [53:51<08:04, 17.96s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 5, 1] before, using random point [0.07695327154122274, 12, 'manhattan', 13, 1]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 5, 1] before, using random point [0.02047973846381485, 16, 'euclidean', 30, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 5, 1] before, using random point [0.03592741460969348, 44, 'manhattan', 34, 3]
#   warnings.warn(
# LOF Tuning for Type 3: 100%|██████████| 200/200 [1:02:00<00:00, 18.60s/it]
# ✅ Saved to lof_scores/lof_type3_scores.csv
#
# 🚀 Running LOF evaluation for anomaly type 4
# LOF Tuning for Type 4:   2%|▏         | 4/200 [01:13<1:01:22, 18.79s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.03304224343050554, 89, 'manhattan', 44, 3]
#   warnings.warn(
# LOF Tuning for Type 4:  15%|█▌        | 30/200 [09:20<50:32, 17.84s/it]  /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'manhattan', 5, 3] before, using random point [0.010696528704479328, 77, 'manhattan', 13, 3]
#   warnings.warn(
# LOF Tuning for Type 4:  28%|██▊       | 55/200 [16:54<45:19, 18.76s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'minkowski', 5, 1] before, using random point [0.014579856861913274, 87, 'manhattan', 14, 3]
#   warnings.warn(
# LOF Tuning for Type 4:  38%|███▊      | 77/200 [23:34<38:13, 18.65s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'euclidean', 5, 1] before, using random point [0.09819218475751085, 80, 'manhattan', 49, 2]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'euclidean', 5, 1] before, using random point [0.03641637768516373, 21, 'manhattan', 21, 3]
#   warnings.warn(
# /data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'euclidean', 5, 1] before, using random point [0.09527347430153597, 65, 'minkowski', 26, 2]
#   warnings.warn(
# LOF Tuning for Type 4:  56%|█████▌    | 112/200 [34:20<27:23, 18.68s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'manhattan', 5, 1] before, using random point [0.03645376034652455, 55, 'minkowski', 16, 2]
#   warnings.warn(
# LOF Tuning for Type 4:  63%|██████▎   | 126/200 [38:42<23:38, 19.17s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 100, 'minkowski', 5, 1] before, using random point [0.026923766433778234, 66, 'euclidean', 19, 2]
#   warnings.warn(
# LOF Tuning for Type 4:  70%|██████▉   | 139/200 [42:41<18:56, 18.64s/it]/data1/home/nitinvetcha/miniconda3/envs/tsfm_anomaly/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 10, 'euclidean', 5, 2] before, using random point [0.03609292630579361, 65, 'minkowski', 35, 2]
#   warnings.warn(
# LOF Tuning for Type 4: 100%|██████████| 200/200 [1:01:34<00:00, 18.47s/it]
# ✅ Saved to lof_scores/lof_type4_scores.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_and_save_score_boxplots(
    score_dir: str,
    output_dir: str = "plots",
    anomaly_types: list = [2, 3, 4],
    prefix: str = "isoforest"
) -> None:
    """
    Generate and save boxplots of F1, Precision, and Recall for each anomaly type.

    Parameters
    ----------
    score_dir : str
        Directory where the per-anomaly-type score CSVs are stored.
    output_dir : str, default "plots"
        Directory where plots will be saved.
    anomaly_types : list of int, default [2, 3, 4]
        List of anomaly types to plot.
    prefix : str, default "isoforest"
        Prefix used in the CSV filenames, e.g., "isoforest_type2_scores.csv".

    Returns
    -------
    None
    """
    os.makedirs(output_dir, exist_ok=True)

    for anomaly_type in anomaly_types:
        print(f"\n📊 Plotting results for anomaly type {anomaly_type}...")

        score_path = os.path.join(score_dir, f"{prefix}_type{anomaly_type}_scores.csv")
        if not os.path.exists(score_path):
            print(f"⚠️ File not found: {score_path}")
            continue

        df = pd.read_csv(score_path)

        if df.empty or df[["f1_score", "precision", "recall"]].isnull().all().all():
            print(f"⚠️ No valid score data for anomaly type {anomaly_type}. Skipping...")
            continue

        # Prepare data
        data = pd.DataFrame({
            "F1 Score": df["f1_score"],
            "Precision": df["precision"],
            "Recall": df["recall"]
        })
        data_melted = data.melt(var_name="Metric", value_name="Score")

        # Plot
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=data_melted, x="Metric", y="Score", palette="Set2")
        plt.title(f"Distribution of F1, Precision, and Recall — Anomaly Type {anomaly_type}")
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.tight_layout()

        out_path = os.path.join(output_dir, f"{prefix}_boxplot_type{anomaly_type}.png")
        plt.savefig(out_path)
        plt.close()

        print(f"✅ Saved boxplot to {out_path}")

# %%
plot_and_save_score_boxplots(
    score_dir="bdg2_lof_scores",   # or "lof_scores"
    output_dir="bdg2_lof_plots",
    anomaly_types=[2, 3, 4],
    prefix="lof"              # change to "lof" if needed
)
# Out:
# 📊 Plotting results for anomaly type 2...
# ✅ Saved boxplot to plots/lof_boxplot_type2.png
#
# 📊 Plotting results for anomaly type 3...
# ✅ Saved boxplot to plots/lof_boxplot_type3.png
#
# 📊 Plotting results for anomaly type 4...
# ✅ Saved boxplot to plots/lof_boxplot_type4.png
